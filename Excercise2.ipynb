# %%
import numpy as np
import pandas as pd
import datetime
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
plt.style.use('seaborn-darkgrid')
plt.rc('figure', figsize=(16,10))
plt.rc('lines', markersize=4)
import yfinance as yf
from sklearn.linear_model import LinearRegression
import statistics as st

# %%
# get close price of big 5
df = pd.read_csv('data/close_price_big_5.csv', index_col=['Date'], infer_datetime_format=True, parse_dates=['Date'])
df.head()
# Out:
#                   AAPL        GOOGL        MSFT         AMZN          FB
# Date
# 2018-12-31  157.740005  1044.959961  101.570000  1501.969971  131.089996
# 2019-01-02  157.919998  1054.680054  101.120003  1539.130005  135.679993
# 2019-01-03  142.190002  1025.469971   97.400002  1500.280029  131.740005
# 2019-01-04  148.259995  1078.069946  101.930000  1575.390015  137.949997
# 2019-01-07  147.929993  1075.920044  102.059998  1629.510010  138.050003

# %%
# decribe include mean, std (standard deviation)
df.describe()
# Out:
#              AAPL        GOOGL        MSFT         AMZN          FB
# count  338.000000   338.000000  338.000000   338.000000  338.000000
# mean   228.339438  1224.055945  139.221657  1845.561064  183.925739
# std     48.112862   114.310050   21.130317   163.873784   18.916758
# min    142.190002  1025.469971   97.400002  1500.280029  131.089996
# 25%    193.922501  1137.094971  125.455002  1753.422485  171.424995
# 50%    212.550003  1205.849976  137.670006  1820.779968  185.620003
# 75%    266.782509  1294.472504  153.532505  1903.930023  196.765003
# max    327.200012  1524.869995  188.699997  2474.000000  223.229996

# %%
# correlation coefficient
df.corr(method='pearson')
# Out:
#            AAPL     GOOGL      MSFT      AMZN        FB
# AAPL   1.000000  0.876155  0.945925  0.562020  0.699672
# GOOGL  0.876155  1.000000  0.774319  0.405623  0.774171
# MSFT   0.945925  0.774319  1.000000  0.731503  0.693364
# AMZN   0.562020  0.405623  0.731503  1.000000  0.461879
# FB     0.699672  0.774171  0.693364  0.461879  1.000000

# %%
# histogram
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize=(16, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002876A793448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875E868688>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875E02F708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875DFEA148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875E0DAB08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002875DF75508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875DFAAE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875E065C08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875E070808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875E0A89C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002875E14FF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875E1C8FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875E203108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875E23D248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875E2B6348>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002875E830448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002875E8A8508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000287603B1608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002876AA78708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002876AAB1848>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002876AAEB988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002876AB23A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002876AB5DB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002876AB94C48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002876ABCDD48>]],
#       dtype=object)

# %%
# covariance
covMatrix = pd.DataFrame.cov(df)
sns.heatmap(covMatrix, annot=True, fmt='g')
plt.show()

# %%
# spearman corr
df.corr(method='spearman')
# Out:
#            AAPL     GOOGL      MSFT      AMZN        FB
# AAPL   1.000000  0.835082  0.960831  0.536714  0.687737
# GOOGL  0.835082  1.000000  0.749841  0.341122  0.722708
# MSFT   0.960831  0.749841  1.000000  0.615445  0.674477
# AMZN   0.536714  0.341122  0.615445  1.000000  0.521760
# FB     0.687737  0.722708  0.674477  0.521760  1.000000
